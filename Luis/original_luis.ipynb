# %%
age = 20
age = 30 # integer
price = 19.95 # Float numbers
my_name = 'Mo' # String
is_online = True # Boolean type
print(is_online)
# Out:
# True

# %%
sand = input('what is yous soil sand percentage?')
print('Thank you: ' + sand + '%')
# Out:
# Thank you: 23%

# %%
first = input('first: ')
second = input ('second: ')
sum = first + second
print(sum)
# Out:
# 2233

# %%
# I am trying to learn about input 
first = input('first: ')
second = input ('second: ')
sum = float(first) + float(second)
print(sum)
print(round(sum),1)
# Out:
# 34.0
# 34 1

# %%
first = input('first: ')
second = input('second: ')
sum = float(first) + float(second)
#print(sum)
print(round(sum, 3))
# Out:
# 56.0

# %%
x1 = 'bayer'
#x1
x1.find('y')
print(x1.replace('r', '5'))
# Out:
# baye5

# %%
print(10/3)
print(10//3)
print(10%3)
# Out:
# 3.3333333333333335
# 3
# 1

# %%
x = 10
#x = 10+2
x +=2
x
# Out:
# 12

# %%
'here' == 'here'
3 != 2
# Out:
# True

# %%
# Logical operations
clay = 47
if clay>25: # conditional statements
    print('you have a coarse soil')
# Out:
# you have a coarse soil

# %%
if clay>50:
    print('It is a fine soil')
elif clay >40:
    print('again same results')
else:
    print('you did it')
# Out:
# again same results

# %%
# List, tuple dictionary and set
# list
numbers = [10,20,30,40,50]
#numbers.append(8) # comment out
numbers
# Out:
# [10, 20, 30, 40, 50]

# %%
# :lists are imputable
# Tupel are not : (10, 20, 30, 4,5)
numbers.insert(2, 8)
numbers
# Out:
# [10, 20, 8, 30, 40, 50]

# %%
numbers[3]
# Out:
# 30

# %%
numbers.remove(20)
numbers
# Out:
# [10, 8, 30, 40, 50]

# %%
s_texture = ['fine', 'sandy', 'loamy', 'clayLoamy']
s_texture.remove('1')
s_texture
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 2
#       1 s_texture = ['fine', 'sandy', 'loamy', 'clayLoamy']
# ----> 2 s_texture.remove('1')
#       3 s_texture
#
# ValueError: list.remove(x): x not in list

# %%
s_texture = ['fine', 'sandy', 'loamy', 'clayLoamy']
s_texture.pop(2)  # removes the element at index 2 (i.e., 30)
s_texture  # Output: [10, 20, 40]
# Out:
# ['fine', 'sandy', 'clayLoamy']

# %%
s_texture = ['fine', 'sandy', 'loamy', 'clayLoamy']
#'loamy_clay' in s_texture
'NaN' in s_texture
# Out:
# False

# %%
#numbers = [10,20,30,40,50]
s_texture = ['fine', 'sandy', 'loamy', 'clayLoamy']
len(s_texture)
# Out:
# 4

# %%
import pandas as pd
myfile=pd.read_csv('mydata.csv')
myfile.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[21], line 2
#       1 import pandas as pd
# ----> 2 myfile=pd.read_csv('mydata.csv')
#       3 myfile.head()
#
# ...

# %%
import pandas as pd
myfile=pd.read_csv('F:\Climate corporation-Bayer-Ettain Group - Copy\practice_python\mydata.csv')
myfile.head()
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\C'
# <>:2: SyntaxWarning: invalid escape sequence '\C'
# C:\Users\Mo\AppData\Local\Temp\ipykernel_11876\3103142873.py:2: SyntaxWarning: invalid escape sequence '\C'
#   myfile=pd.read_csv('F:\Climate corporation-Bayer-Ettain Group - Copy\practice_python\mydata.csv')
#    Unnamed: 0       name sex mindset  math_score  bio_score  age student_job  \
# 0           0  Student_1   F    Good          73         81   17   Part-time
# 1           1  Student_2   M    Fair         100         84   17         NaN
# 2           2  Student_3   M  Expert          81         88   17   Part-time
# 3           3  Student_4   F    Fair          88         97   16         NaN
# 4           4  Student_5   M  Expert          93         70   17         NaN
#
#      GP  studytime
# 0  3.10          4
# 1  3.33          2
# 2  2.75          3
# 3  3.05          2
# 4  2.72          4

# %% [markdown]
# Matplotlib

# %%
import matplotlib.pyplot as plt
# plt.plot(x, y)
plt.plot(myfile['age'], myfile['bio_score'])
plt.show()

# %%
myfile=pd.read_csv('F:\Climate corporation-Bayer-Ettain Group - Copy\practice_python\weather_2.csv')
myfile.head()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\C'
# <>:1: SyntaxWarning: invalid escape sequence '\C'
# C:\Users\Mo\AppData\Local\Temp\ipykernel_11876\3195636415.py:1: SyntaxWarning: invalid escape sequence '\C'
#   myfile=pd.read_csv('F:\Climate corporation-Bayer-Ettain Group - Copy\practice_python\weather_2.csv')
#    t  hum%  Tmax  Tmin  Rain   rainydays    Hum
# 0  1  69.5  10.5   2.5    2.0          1  0.695
# 1  2  52.2  11.5  -1.5    0.0          0  0.522
# 2  3  60.5  13.5  -0.5    0.0          0  0.605
# 3  4  66.7  12.5   0.5    0.0          0  0.667
# 4  5  46.0  12.5  -1.5    0.0          0  0.460

# %%
print(myfile.columns.tolist())
# Out:
# ['t', 'hum%', 'Tmax', 'Tmin', 'Rain ', 'rainydays', 'Hum']

# %%
plt.plot(myfile['hum%'], myfile['Hum'])
plt.show()

# %%
import numpy as np
x= np.linspace(1, 10, 100)
y = x ** 2
plt.plot(x,y)
plt.show()

# %%
x= np.linspace(-5, 5, 100)
y = x ** 2
plt.plot(x,y)
plt.show()

# %%
x= np.linspace(-5, 5, 100)
y = x ** 2
plt.plot(x,y, color = 'red')
plt.title('sample graph')
plt.xlabel('Independant variable')
plt.ylabel('dependent variable')
plt.show()

# %%
x= np.linspace(-5, 5, 100)
y = x ** 2
y2 = x ** 3
plt.plot(x,y, color = 'red')
plt.plot(x, y2, color='blue')
plt.title('sample graph')
plt.xlabel('Independant variable')
plt.ylabel('dependent variable')
plt.show()

# %%
x= np.linspace(-5, 5, 100)
y = x ** 2
y2 = x ** 3
plt.plot(x,y, color = 'red')
plt.plot(x, y2, color='blue')
plt.title('sample graph')
plt.xlabel('Independant variable')
plt.ylabel('dependent variable')
plt.legend(['y', 'y2'])
plt.show()

# %%
x= np.linspace(-5, 5, 100)
y = x ** 2
y2 = x ** 3
plt.plot(x,y, color = 'red')
plt.plot(x, y2, color='blue')
plt.title('sample graph')
plt.xlabel('Independant variable')
plt.ylabel('dependent variable')
plt.legend(['y', 'y2'])

print(plt.style.available)
#plt.show()
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'petroff10', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
x= np.linspace(-5, 5, 100)
y = x ** 2
y2 = x ** 3

plt.style.use('dark_background')

plt.plot(x,y, color = 'red')
plt.plot(x, y2, color='blue')
plt.title('sample graph')
plt.xlabel('Independant variable')
plt.ylabel('dependent variable')
plt.legend(['y', 'y2'])

print(plt.style.available)
#plt.show()
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'petroff10', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
x= np.linspace(-5, 5, 100)
y = x ** 2
y2 = x ** 3
plt.plot(x,y, color = 'red')
plt.plot(x, y2, color='blue')
plt.title('sample graph')
plt.xlabel('Independant variable')
plt.ylabel('dependent variable')
plt.legend(['y', 'y2'], labelcolor='black')
plt.show()

# %%
x= np.linspace(-5, 5, 100)
y = x ** 2
y2 = x ** 3
plt.style.use('ggplot')

plt.plot(x,y, color = 'red', linewidth=5)

plt.plot(x, y2, color='blue')
plt.title('sample graph')
plt.xlabel('Independant variable')
plt.ylabel('dependent variable')
plt.legend(['y', 'y2'])
plt.show()

# %%
x= np.linspace(-5, 5, 100)
y = x ** 2
y2 = x ** 3
plt.style.use('ggplot')

plt.plot(x,y, color = 'red', linewidth=5, linestyle='--')

plt.plot(x, y2, color='blue')
plt.title('sample graph')
plt.xlabel('Independant variable')
plt.ylabel('dependent variable')
plt.legend(['y', 'y2'])
plt.show()

# %%
# save the graph
x= np.linspace(-5, 5, 100)
y = x ** 2
y2 = x ** 3
plt.style.use('ggplot')
plt.plot(x,y, color = 'red', linewidth=5, linestyle='--')
plt.plot(x, y2, color='blue')
plt.title('sample graph')
plt.xlabel('Independant variable')
plt.ylabel('dependent variable')

#plt.savefig('sample_graph_save.png')
plt.savefig('sample_graph_save.pdf')

plt.legend(['y', 'y2'])
plt.show()

# %%
# change the figure size
x= np.linspace(-5, 5, 100)
y = x ** 2
y2 = x ** 3
plt.style.use('ggplot')

plt.figure(figsize=(6,4))
           
plt.plot(x,y, color = 'red', linewidth=5, linestyle='--')
plt.plot(x, y2, color='blue')
plt.title('sample graph')
plt.xlabel('Independant variable')
plt.ylabel('dependent variable')
#plt.savefig('sample_graph_save.png')
plt.savefig('sample_graph_save.pdf')
plt.legend(['y', 'y2'])
plt.show()

# %%
# change the figure size
x= np.linspace(-5, 5, 100)
y = x ** 2
y2 = x ** 3
plt.style.use('ggplot')

plt.figure(figsize=(6,4), dpi=200)
           
plt.plot(x,y, color = 'red', linewidth=5, linestyle='--')
plt.plot(x, y2, color='blue')
plt.title('sample graph')
plt.xlabel('Independant variable')
plt.ylabel('dependent variable')
#plt.savefig('sample_graph_save.png')
plt.savefig('sample_graph_save.pdf')
plt.legend(['y', 'y2'])
plt.show()

# %%
import pandas as pd
myweather=pd.read_csv('F:\Climate corporation-Bayer-Ettain Group - Copy\practice_python\weather_2.csv')
myweather.head()
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\C'
# <>:2: SyntaxWarning: invalid escape sequence '\C'
# C:\Users\Mo\AppData\Local\Temp\ipykernel_11876\503037023.py:2: SyntaxWarning: invalid escape sequence '\C'
#   myweather=pd.read_csv('F:\Climate corporation-Bayer-Ettain Group - Copy\practice_python\weather_2.csv')
#    t  hum%  Tmax  Tmin  Rain   rainydays    Hum
# 0  1  69.5  10.5   2.5    2.0          1  0.695
# 1  2  52.2  11.5  -1.5    0.0          0  0.522
# 2  3  60.5  13.5  -0.5    0.0          0  0.605
# 3  4  66.7  12.5   0.5    0.0          0  0.667
# 4  5  46.0  12.5  -1.5    0.0          0  0.460

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(myweather['Hum'], myweather['Tmax'])
plt.plot(myweather['Hum'], myweather['Tmin'])
plt.plot(myweather['Hum'], myweather['Rain '])
plt.show()

# %%
#only parts of days
subset=myweather[(myweather['t']>100) & (myweather['t']<=150)]

plt.plot(subset['Hum'], subset['Tmax'], label='Tmax')
plt.plot(subset['Hum'], subset['Tmin'], label='Tmin')
plt.plot(subset['Hum'], subset['Rain '], label='Rain')
plt.show()

# %%
plt.style.use('default')

plt.scatter(subset['Hum'], subset['Tmax'], label='Tmax')
plt.scatter(subset['Hum'], subset['Tmin'], label='Tmin')
plt.scatter(subset['Hum'], subset['Rain '], label='Rain')
plt.legend()
plt.show()

# %%
plt.scatter(subset['Hum'], subset['Tmax'], label='Tmax')
plt.scatter(subset['Hum'], subset['Tmin'], label='Tmin')
plt.scatter(subset['Hum'], subset['Rain '], label='Rain')

plt.grid()

plt.legend()
plt.show()

# %%
x = [1, 2, 3, 4]
y = [4, 5, 7, 10]
plt.bar(x, y)
plt.show()

# %%
subset2=myweather[(myweather['t']>130) & (myweather['t']<=135)]

plt.bar(subset2['Hum'], subset2['Tmax'], label='Tmax')
#plt.bar(subset2['Hum'], subset2['Tmin'], label='Tmin')
#plt.bar(subset2['Hum'], subset2['Rain '], label='Rain')
plt.show()

# %%
# hum is float and sothe bars overlap, how to change:
plt.bar(subset2['Hum'], subset2['Tmax'], width=0.5, label='Tmax')  # width < 1 adds space
plt.show()

# %%
# (subset2['Hum']) likely has very small differences between values (e.g., 69.5, 69.6, 69.7), so the bars still appear stuck together
subset2['HumCat'] = subset2['Hum'].round(1)  # round or bin humidity to reduce crowding
#{s} we change the x as days number
x = range(len(subset2))
plt.bar(x, subset2['Tmax'], width=0.5, label='Tmax')
plt.show()
# Out:
# C:\Users\Mo\AppData\Local\Temp\ipykernel_11876\1254856773.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset2['HumCat'] = subset2['Hum'].round(1)  # round or bin humidity to reduce crowding

# %%
# subset2 = subset2.rename(columns={'t', 'day'})
subset2['Day_of_Year']=subset2['t']
plt.bar(subset2['Day_of_Year'], subset2['Tmax'], width=0.6, label='Tmax')  # width < 1 adds space

plt.title('Tmax for Days 131 to 135')

plt.show()
# Out:
# C:\Users\Mo\AppData\Local\Temp\ipykernel_11876\3199944861.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset2['Day_of_Year']=subset2['t']

# %%
subset.head()
# Out:
#        t  hum%  Tmax  Tmin  Rain   rainydays    Hum
# 100  101  57.3  25.5  13.5    0.0          0  0.573
# 101  102  48.0  27.5  10.5    0.0          0  0.480
# 102  103  46.0  30.5  10.5    0.0          0  0.460
# 103  104  58.3  27.5  13.5    0.0          0  0.583
# 104  105  71.3  22.5  12.5    0.0          0  0.713

# %% [markdown]
# Some adding advanced stuff

# %%
# adding another feature
subset['Rain '].value_counts()
# Out:
# Rain
# 0.0    41
# 2.0     3
# 4.0     1
# 5.0     1
# 0.5     1
# 0.2     1
# 0.6     1
# 3.0     1
# Name: count, dtype: int64

# %%
subset['wet_dry'] = subset['Rain '].apply(lambda x: 'wet' if x>0 else 'dry')
subset.head()
# Out:
# C:\Users\Mo\AppData\Local\Temp\ipykernel_11876\2883011957.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset['wet_dry'] = subset['Rain '].apply(lambda x: 'wet' if x>0 else 'dry')
#        t  hum%  Tmax  Tmin  Rain   rainydays    Hum wet_dry
# 100  101  57.3  25.5  13.5    0.0          0  0.573     dry
# 101  102  48.0  27.5  10.5    0.0          0  0.480     dry
# 102  103  46.0  30.5  10.5    0.0          0  0.460     dry
# 103  104  58.3  27.5  13.5    0.0          0  0.583     dry
# 104  105  71.3  22.5  12.5    0.0          0  0.713     dry

# %%
w_condition = subset['wet_dry'].value_counts()
w_condition
# Out:
# wet_dry
# dry    41
# wet     9
# Name: count, dtype: int64

# %%
data = {
    "name": ["Alice", "Bob"],
    "age": [30, 25],
    "city": ["New York", "Los Angeles"]
}

df = pd.DataFrame(data)
print(df)
# Out:
#     name  age         city
# 0  Alice   30     New York
# 1    Bob   25  Los Angeles

# %%
w_condition=w_condition.to_dict()

# %%
drought = list(w_condition.keys())
flood = list(w_condition.values())

# %%
plt.bar(drought, flood)
plt.show()

# %%
components = [25, 31, 44] # soil physical 
plt.pie(components)
plt.show()

# %%
components = [25, 31, 44] # soil physical 

textures = ['sand', 'silt', 'clay']

plt.pie(components, labels=textures)
plt.show()

# %%
components = [8, 5, 3, 0.7, 0.5, 0.1] # soil physical 

nutrients = ['N', 'P', 'K', 'S', 'Ca', 'Si']

plt.pie(components, labels=nutrients)
plt.show()

# %%
#our own clor selection
components = [8, 5, 3, 0.7, 0.5, 0.1] # soil physical 
nutrients = ['N', 'P', 'K', 'S', 'Ca', 'Si']

colors = ['gray', 'purple', 'pink', 'orange', 'brown', 'khaki']

plt.pie(components, labels=nutrients, colors=colors)
plt.show()

# %%
# highlite an important piece for example: 
components = [8, 5, 3, 0.7, 0.5, 0.1] # soil physical 
nutrients = ['N', 'P', 'K', 'S', 'Ca', 'Si']
colors = ['gray', 'purple', 'pink', 'orange', 'brown', 'khaki']

explode = [0,0,0.2,0,0, 0]
plt.pie(components, labels=nutrients, colors=colors, explode=explode)

plt.show()

# %%
# Shadow make it 3D
components = [8, 5, 3, 0.7, 0.5, 0.1] # soil physical 
nutrients = ['N', 'P', 'K', 'S', 'Ca', 'Si']
colors = ['gray', 'purple', 'pink', 'orange', 'brown', 'khaki']
explode = [0,0,0.2,0,0, 0]

plt.pie(components, labels=nutrients, colors=colors, explode=explode, shadow = True)

plt.show()

# %%
# Write its persentage
components = [8, 5, 3, 2, 1, 0.5] # soil physical 
nutrients = ['N', 'P', 'K', 'S', 'Ca', 'Si']
colors = ['gray', 'purple', 'pink', 'orange', 'brown', 'khaki']
explode = [0,0,0.2,0,0, 0]

plt.pie(components, labels=nutrients, colors=colors, explode=explode, shadow = True, autopct='%1.1f')

plt.show()

# %% [markdown]
# ### Stackplot >> Time series of data, and their share from all

# %%
# Location A: clay, sand, silt
#location B:
# Location C:
values = [1,2,3,4,5,6]
A = [15, 55, 30, 11, 21, 17]
B = [25, 5, 70, 13, 6, 21]
C = [20, 25, 55, 66, 3, 15]

plt.stackplot(values, A, B, C)

# %%
values = [1,2,3,4,5,6]
A = [15, 55, 30, 11, 21, 17]
B = [25, 5, 70, 13, 6, 21]
C = [20, 25, 55, 66, 3, 15]

#labels
labels = ['irrigation1', 'irrigation2', 'irrigation3']

plt.stackplot(values, A, B, C, labels = labels)
plt.legend()
plt.show()
