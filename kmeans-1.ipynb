# %%
import sklearn
from sklearn.datasets import load_digits
import matplotlib.pyplot as plt 
import numpy as np
from sklearn.model_selection import train_test_split 
from sklearn.decomposition import PCA

# %%
data = load_digits()
X=data.data
y=data.target

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1)

# %%
data.target[1200]
# Out:
# 7

# %%
img = data.data[1200].reshape(8,8)
plt.imshow(img)
plt.show()

# %%
model=KMeans(n_clusters=10, init='random', n_init=20)

# %%
model.fit(X_train, y_train)
# Out:
# KMeans(init='random', n_clusters=10, n_init=20)

# %%
model.score(X_test, y_test)
# Out:
# -118649.31171443121

# %%
predictions= model.predict(X_test)

# %%
#How many correct or wrong

true=0
false=0
for i in range(len(X_test)):
    if predictions[i]==y_test[1]:
        true+=1
    else:
        false+=1
print(true, false)
# Out:
# 16 164

# %%
samples={}
for i in data.target:
    if i not in samples:
        samples[i]=1
    else:
        samples[i]+=1
print(samples)
# Out:
# {0: 178, 1: 182, 2: 177, 3: 183, 4: 181, 5: 182, 6: 181, 7: 179, 8: 174, 9: 180}

# %%
##### groups of data are not the same, so for those that has nto enough data lets generate data
#### Better not use Score for kmeans as metric

# %%
reduced_data=PCA(n_components=2).fit_transform(X)

# %%
kmeans=KMeans(init="k-means++", n_clusters=10, n_init=4)
kmeans.fit(reduced_data)
# Out:
# KMeans(n_clusters=10, n_init=4)
